# %%
from tasks.odds import get_odds
from tasks.keys import SES_HOST_ADDRESS, SES_USER_ID, SES_PASSWORD, ODDS_API_KEY

# %%
df = get_odds("americanfootball_nfl", ODDS_API_KEY, "us", "fanduel", "american")

# %%
df
# Out:
#     home_team_odds  away_team_odds         commence_time  \
# 0             -320             260  2023-10-06T00:15:00Z
# 1             -230             190  2023-10-08T13:30:00Z
# 2             -116            -102  2023-10-08T17:00:00Z
# 3             -420             330  2023-10-08T17:00:00Z
# 4             -120             102  2023-10-08T17:00:00Z
# 5             -116            -102  2023-10-08T17:00:00Z
# 6              190            -230  2023-10-08T17:00:00Z
# 7             -480             370  2023-10-08T17:01:00Z
# 8              140            -166  2023-10-08T20:05:00Z
# 9              176            -210  2023-10-08T20:05:00Z
# 10            -130             110  2023-10-08T20:26:00Z
# 11             194            -235  2023-10-08T20:26:00Z
# 12            -178             150  2023-10-09T00:20:00Z
#
#                 home_team             away_team
# 0   Washington Commanders         Chicago Bears
# 1           Buffalo Bills  Jacksonville Jaguars
# 2         Atlanta Falcons        Houston Texans
# 3           Detroit Lions     Carolina Panthers
# 4      Indianapolis Colts      Tennessee Titans
# 5    New England Patriots    New Orleans Saints
# 6     Pittsburgh Steelers      Baltimore Ravens
# 7          Miami Dolphins       New York Giants
# 8       Arizona Cardinals    Cincinnati Bengals
# 9        Los Angeles Rams   Philadelphia Eagles
# 10         Denver Broncos         New York Jets
# 11      Minnesota Vikings    Kansas City Chiefs
# 12    San Francisco 49ers        Dallas Cowboys

# %%
from tasks.predict import predict
# Out:
# 2023-10-02 15:09:43.056502: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = predict(df)
# Out:
# Random features:  [[0.00530801]
#  [0.41507046]
#  [0.0395088 ]
#  [0.33628583]
#  [0.91977144]
#  [0.21468733]
#  [0.1322331 ]
#  [0.23247957]
#  [0.19671666]
#  [0.16030678]
#  [0.1073951 ]
#  [0.74751643]
#  [0.77919201]]
# 1/1 [==============================] - 0s 67ms/step
# 2023-10-02 15:09:47.399457: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df
# Out:
#     home_team_odds  away_team_odds         commence_time  \
# 0             -320             260  2023-10-06T00:15:00Z
# 1             -230             190  2023-10-08T13:30:00Z
# 2             -116            -102  2023-10-08T17:00:00Z
# 3             -420             330  2023-10-08T17:00:00Z
# 4             -120             102  2023-10-08T17:00:00Z
# 5             -116            -102  2023-10-08T17:00:00Z
# 6              190            -230  2023-10-08T17:00:00Z
# 7             -480             370  2023-10-08T17:01:00Z
# 8              140            -166  2023-10-08T20:05:00Z
# 9              176            -210  2023-10-08T20:05:00Z
# 10            -130             110  2023-10-08T20:26:00Z
# 11             194            -235  2023-10-08T20:26:00Z
# 12            -178             150  2023-10-09T00:20:00Z
#
#                 home_team             away_team  home_team_predicted_odds  \
# 0   Washington Commanders         Chicago Bears                 48.651768
# 1           Buffalo Bills  Jacksonville Jaguars                 48.651764
# 2         Atlanta Falcons        Houston Texans                 48.651768
# 3           Detroit Lions     Carolina Panthers                 48.651768
# 4      Indianapolis Colts      Tennessee Titans                 48.651772
# 5    New England Patriots    New Orleans Saints                 48.651772
# 6     Pittsburgh Steelers      Baltimore Ravens                 48.651768
# 7          Miami Dolphins       New York Giants                 48.651768
# 8       Arizona Cardinals    Cincinnati Bengals                 48.651768
# 9        Los Angeles Rams   Philadelphia Eagles                 48.651768
# 10         Denver Broncos         New York Jets                 48.651772
# 11      Minnesota Vikings    Kansas City Chiefs                 48.651764
# 12    San Francisco 49ers        Dallas Cowboys                 48.651772
#
#     away_team_predicted_odds
# 0                  51.348232
# 1                  51.348228
# 2                  51.348232
# 3                  51.348232
# 4                  51.348232
# 5                  51.348232
# 6                  51.348232
# 7                  51.348232
# 8                  51.348232
# 9                  51.348232
# 10                 51.348232
# 11                 51.348232
# 12                 51.348232
